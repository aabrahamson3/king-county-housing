# %%
import psycopg2 as pg
from sqlalchemy import create_engine

# get connected to the database
engine = create_engine('postgresql:///kc_housing')

query_string = """
    SELECT *
    FROM rpsale INNER JOIN 
    
    """

df_par = pd.read_sql_query('Select * From parcel',con=engine)

# %%
df_par['id'] = df_par.Major.astype(str)+df_par.Minor.astype(str)
df_rps['id'] = df_rps.Major.astype(str)+df_rps.Minor.astype(str)
df_bldg['id'] = df_bldg.Major.astype(str)+df_bldg.Minor.astype(str)
# Out:
#     major minor                                           propname  \
# 0  889250  0080                                                ...
# 1  736360  0275                                                ...
# 2  600350  0635                                                ...
# 3  635260  0760                                                ...
# 4  333250  0015                                                ...
#
#                                             platname         platlot  \
# 0  VELKOFF JOHN ADD                              ...  8
# 1  ROBERTS JAY COUNTRY CLUB ESTATES              ...  8
# 2  NAGLES 2ND ADD                                ...  6
# 3  OLD MILL POINT                                ...  TRACT I
# 4  HILLMAN CITY DIV NO. 05                       ...  3-4
#
#   platblock  range  township  section quartersection  ... seismichazard  \
# 0              5.0      22.0      8.0             SE  ...             N
# ...
